# %%
# In[28]:

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math
import sys


car_path = r"D:\Z_zDCVS_space\7976_aion_slant_parking\7976_20220421/"

path_car_file = car_path+"computed_path.txt"

print("car path: ", path_car_file)
# Out:
# car path:  D:\Z_zDCVS_space\7976_aion_slant_parking\7976_20220421/computed_path.txt

# %%
# load computed path files
path_carx = []
path_cary = []
try:
    with (open(path_car_file,"r")) as f:
        for line in f:
            if ("x y" not in line):
                path_carx.append(float(line.split()[0]))
                path_cary.append(float(line.split()[1]))
except:
    print("Unexpected error:", sys.exc_info()[0])

# %%
plt.figure(figsize=(8,10))

# 1. plot computed path
plt.plot(path_carx, path_cary, label="car_path1", linewidth=4, alpha=0.5)

plt.legend(loc="best")


plt.show()
