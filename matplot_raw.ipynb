# %%
import matplotlib.pyplot as plt

ax = plt.axes()
ax.arrow(0, 0, 0.5, 0.5, head_width=0.05, head_length=0.1, fc='k', ec='k')
plt.show()

# %%
import matplotlib.pyplot as plt

ax = plt.axes()
# ax.arrow(1.80147, -5.49878, 2.8010, -5.4714, head_width=0.05, head_length=0.1, fc='k', ec='k')
ax.arrow(1.80147, -5.49878, 0, 0.99, head_width=0.3, head_length=0.1)

plt.show()
